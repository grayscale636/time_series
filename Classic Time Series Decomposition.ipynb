# %% [markdown]
# # Classic Time Series Decomposition -> 1920
#
# Teknik untuk memisahkan time series menjadi trend, seasonal, dan residual menggunakan Moving Average. Ada 2 tipe:
#
# `additive = Trend + Seasonal + Residual`<br>
# `multiplicative = Trend + Seasonal + Residual`
#
# Additve dipakai pada **trend dan seasonal yang tidak terlalu bervariasi**<br>
# multiplicative dipakai pada **trend dan seasonal yang berubah seiring berjalannya waktu**
#
# Contoh:
# - Additive : Terdapat peningkatan oelanggan 10000 orang / tahun
# - Multiplicative = Terdapat peningkatan pelanggan 10% / tahun

# %% [markdown]
# ## Contoh Additive

# %%
import pandas as pd
from jcopml.time_series.decomposition import additive_decomposition, multiplicative_decomposition, stl_decomposition

# %%
df = pd.read_csv('data/cheese_fred.csv', index_col='date', parse_dates=['date'])
series = df.total_cheese_production
series.plot(figsize=(15, 3))
# Out:
# <Axes: xlabel='date'>

# %%
additive_decomposition(series, plot=True)

# %% [markdown]
# ## Contoh Multiplicative

# %%
df = pd.read_csv('data/airline.csv', index_col='Date', parse_dates=['Date'])
series = df.passengers
series.plot(figsize=(15, 3))
# Out:
# <Axes: xlabel='Date'>

# %%
multiplicative_decomposition(series, plot=True)

# %% [markdown]
# ### Seasonal-Trend decomposition with LOESS (STL) -> 1990
# LOESS (locally estimated scatterplot smoothing) mulanya di desain untuk smoothing scatterplot. Idenya adalah menggunakan Moving Regression.
#
# STL sendiri memiliki beberapa kelebihan:
# - komponen seasonal bisa berubah seiring waktu
# - smoothing pada trend dan seasonal

# %%
df = pd.read_csv('data/airline.csv', index_col='Date', parse_dates=['Date'])
series = df.passengers
series.plot(figsize=(15, 3))
# Out:
# <Axes: xlabel='Date'>

# %%
components = stl_decomposition(series, plot=True)

# %% [markdown]
# ## Seasonal vs Cyclical
# ada perbedaan antara seasonal dan cyclical. Cyclical bergerak naik-turun secara aperiodik (tanpa periode yang tetap)
