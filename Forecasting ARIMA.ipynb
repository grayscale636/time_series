# %%
import pandas as pd
import matplotlib.pyplot as plt

from luwiji.time_series import illustration, demo

# %% [markdown]
# ## Konsep Stationarity
#
# sebuah time series disebut seasonary ketika sifatnya tidak bergantung terhadap waktu. Time series yang stationary tidak memiliki pola yang predictable pada jangka waktu yang panjang. Contoh:
#
# - stationary: white noise, cyclical time series yang **aperiodic, tanpa trend, tanpa seasonality**
# - tidak stationary: time series dengan trend atau seasonality

# %%
illustration.stationarity_quiz
